# %%
# Bài 1:
def bai1():
    # Nhập mảng a
    a = list(map(int, input("Nhập mảng a (các số cách nhau): ").split()))
    # Nhập mảng b
    b = list(map(int, input("Nhập mảng b (các số cách nhau): ").split()))
    result = []
    min_len = min(len(a), len(b))
    for i in range(min_len):
        result.append(min(a[i], b[i]))
    # Thêm phần tử còn lại
    if len(a) > min_len:
        result.extend(a[min_len:])
    if len(b) > min_len:
        result.extend(b[min_len:])
    print("Mảng kết quả:", result)
bai1()
# Out:
# Nhập mảng a (các số cách nhau): 3 9 1 4
# Nhập mảng b (các số cách nhau): 2 7 4 3 2 8
# Mảng kết quả: [2, 7, 1, 3, 2, 8]

# %%
#Bai 2
# Define a sample square matrix for testing
a = [
    [1, 2, 3],
    [4, -5, 6],
    [7, 8, 9]
]
print("Original matrix:", a)

# Test a. Tính tổng các phần tử thuộc tam giác trên của đường chéo phụ kề cả đường chéo phụ
print("\nTổng các phần tử thuộc tam giác trên của đường chéo phụ:", sum_triangle_above_secondary_diag(a))

# Test b. Chuyển các phần tử âm thành trị tuyệt đối của nó
# Create a copy to avoid modifying the original matrix for subsequent tests
a_copy_abs = [row[:] for row in a]
abs_negative(a_copy_abs)
print("\nMa trận sau khi chuyển phần tử âm thành trị tuyệt đối:", a_copy_abs)

# Test c. Thay các phần tử chẵn trong a bằng số nguyên x cho trước
# Create another copy
a_copy_replace = [row[:] for row in a]
x_replace = 0 # Example replacement value
replace_even(a_copy_replace, x_replace)
print(f"\nMa trận sau khi thay các phần tử chẵn bằng {x_replace}:", a_copy_replace)

# Test d. Kiểm tra a có toàn chẵn không?
print("\nMa trận có toàn chẵn không:", all_even(a))

# Test e. Kiểm tra a có đối xứng không.
# Example symmetric matrix
symmetric_a = [
    [1, 2, 3],
    [2, 5, 6],
    [3, 6, 9]
]
print("\nMa trận đối xứng ví dụ:", symmetric_a)
print("Ma trận đối xứng ví dụ có đối xứng không:", is_symmetric(symmetric_a))
print("Ma trận gốc có đối xứng không:", is_symmetric(a))

# Test f. Kiểm tra ma trận vuông a cấp n có đường chéo chính tăng dần không?
# Example increasing main diagonal matrix
increasing_diag_a = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
print("\nMa trận đường chéo chính tăng dần ví dụ:", increasing_diag_a)
print("Ma trận đường chéo chính tăng dần ví dụ có tăng dần không:", main_diag_increasing(increasing_diag_a))
print("Ma trận gốc có đường chéo chính tăng dần không:", main_diag_increasing(a))

# Test g. Xuất các phần tử thuộc tam giác dưới của đường chéo phụ kề cả đường chéo phụ
print("\nCác phần tử thuộc tam giác dưới của đường chéo phụ:")
print_triangle_below_secondary_diag(a)

# Test h. Kiểm tra ma trận vuông a cấp n có đường chéo phụ giảm dần không?
# Example decreasing secondary diagonal matrix
decreasing_sec_diag_a = [
    [1, 2, 9],
    [4, 5, 3],
    [7, 8, 2]
]
print("\nMa trận đường chéo phụ giảm dần ví dụ:", decreasing_sec_diag_a)
print("Ma trận đường chéo phụ giảm dần ví dụ có giảm dần không:", secondary_diag_decreasing(decreasing_sec_diag_a))
print("Ma trận gốc có đường chéo phụ giảm dần không:", secondary_diag_decreasing(a))
# Out:
# Original matrix: [[1, 2, 3], [4, -5, 6], [7, 8, 9]]
#
# Tổng các phần tử thuộc tam giác trên của đường chéo phụ: 12
#
# Ma trận sau khi chuyển phần tử âm thành trị tuyệt đối: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
#
# Ma trận sau khi thay các phần tử chẵn bằng 0: [[1, 0, 3], [0, -5, 0], [7, 0, 9]]
#
# Ma trận có toàn chẵn không: False
#
# Ma trận đối xứng ví dụ: [[1, 2, 3], [2, 5, 6], [3, 6, 9]]
# Ma trận đối xứng ví dụ có đối xứng không: True
# Ma trận gốc có đối xứng không: False
#
# Ma trận đường chéo chính tăng dần ví dụ: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Ma trận đường chéo chính tăng dần ví dụ có tăng dần không: True
# Ma trận gốc có đường chéo chính tăng dần không: False
#
# Các phần tử thuộc tam giác dưới của đường chéo phụ:
# [3, -5, 6, 7, 8, 9]
#
# Ma trận đường chéo phụ giảm dần ví dụ: [[1, 2, 9], [4, 5, 3], [7, 8, 2]]
# Ma trận đường chéo phụ giảm dần ví dụ có giảm dần không: False
# Ma trận gốc có đường chéo phụ giảm dần không: False
